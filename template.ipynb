# %%
# %%HTML
# <script src="dist/reveal.js"></script>
# <script>
# Reveal.initialize({
#   // The "normal" size of the presentation, aspect ratio will
#   // be preserved when the presentation is scaled to fit different
#   // resolutions. Can be specified using percentage units.
#   width: 1200,
#   height: 800,
#
#   // Factor of the display size that should remain empty around
#   // the content
#   margin: 0.04,
#
#   // Bounds for smallest/largest possible scale to apply to content
#   minScale: 0.2,
#   maxScale: 2.0
#
#   // Overwrite that vertical alignment is not to the middle of the slide
#   center: false
# }
# </script
#
# <!-- reveal.js CSS theme and local overrides -->
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700&amp;lang=en"/>
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Merriweather:italic&amp;lang=en"/>
# <link rel="stylesheet" href="https://raw.githubusercontent.com/jossl95/RISE_template/main/template.css?token=ALLGDCINKYWXJARXCULHGNTAGP6IQ"/>
# Out:
# <script src="dist/reveal.js"></script>
# <script>
# Reveal.initialize({
#   // The "normal" size of the presentation, aspect ratio will
#   // be preserved when the presentation is scaled to fit different
#   // resolutions. Can be specified using percentage units.
#   width: 1200,
#   height: 800,
#
#   // Factor of the display size that should remain empty around
#   // the content
#   margin: 0.04,
#
#   // Bounds for smallest/largest possible scale to apply to content
#   minScale: 0.2,
#   maxScale: 2.0
#
#   // Overwrite that vertical alignment is not to the middle of the slide
#   center: false
# }
# </script
#
# <!-- reveal.js CSS theme and local overrides -->
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700&amp;lang=en"/>
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Merriweather:italic&amp;lang=en"/>
# <link rel="stylesheet" href="https://raw.githubusercontent.com/jossl95/RISE_template/main/template.css?token=ALLGDCINKYWXJARXCULHGNTAGP6IQ"/>

# %%
import pandas as pd
import os
from IPython.display import HTML

# # set list of colors for plotting
# uu_colors = []

# This line will add a button to toggle visibility of code blocks,
# for use with the HTML export version
toggle = HTML('''<button style="margin:0 auto; display: block;" onclick="jQuery('.code_cell .input_area').toggle();
    jQuery('.prompt').toggle();">Toggle code</button>''')
toggle
# Out:
# <button style="margin:0 auto; display: block;" onclick="jQuery('.code_cell .input_area').toggle();
#     jQuery('.prompt').toggle();">Toggle code</button>

# %% [markdown]
# <section id="title-slide">
#     <div id='rise-header'><img id="logo" src="./img/uu-logo.png"></div>
#     <br><br><br><h1><i>Title goes here</i></h1>
#     <h4><i>Subtitle goes here</i></h4>
#     <br><br><br><br><br><br>
#     <div class="uu_title_container">
#         <smaller>
#         <div class='column'>
#             <b>Presented by:</b><br> Name of Presenter<sup><small>1</small></sup>
#         </div>
#         <div class='column'>
#             <b>Co-Authors: </b><br> Co-author 1<sup><small>1,2</small></sup>&amp; Co-author 2<sup><small>1,3</small></sup>
#             </div></smaller>
#     </div><br>
#     <div id='rise-footer'>
#         <b>1.</b> Utrecht University, <b>2.</b> Affiliation 2, <b>3.</b> Affiliation 3
#     </div>
# </section>

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="uu_title_container">
#     <div class='column'>
#         <h2>Introduction</h2>
#         <p>Lorem ipsum dolor sit amet, consectetur adipiscing elit. Duis venenatis luctus ante sed interdum. Proin arcu urna, gravida vitae interdum et, congue ac metus. Cras ornare purus lacinia, convallis risus fringilla, accumsan erat. Aenean porttitor pellentesque tellus, a gravida mauris laoreet vitae.</p>
#     </div>
#     <div class='column' id='frame'>
#         <figure><center><img id="col_img" src="https://static01.nyt.com/images/2019/10/02/video/02-still-for-america-room-loop/02-still-for-america-room-loop-superJumbo.jpg?quality=90&auto=webp"><div id='image_caption'>New York Times</div></center></figure>
#     </div>
# </div>

# %% [markdown]
# <div class="uu_title_container">
#     <div class='column'>
#         <h2>Theory</h2>
#         <p>Lorem ipsum dolor sit amet, consectetur adipiscing elit. Duis venenatis luctus ante sed interdum. Proin arcu urna, gravida vitae interdum et, congue ac metus. Cras ornare purus lacinia, convallis risus fringilla, accumsan erat. Aenean porttitor pellentesque tellus, a gravida mauris laoreet vitae.</p>
#     </div>
#     <div class='column' id='frame'>
#         <br><br><br>
#         <center><img id="undraw_col_img" src="./img/undraw_lightbulb.svg"></center>
#     </div>
# </div>

# %% [markdown]
# <figure><center><img id="full_screen" src="https://static01.nyt.com/images/2019/10/02/video/02-still-for-america-room-loop/02-still-for-america-room-loop-superJumbo.jpg?quality=90&auto=webp"><div id='image_caption'>New York Times</div></center><figure>

# %% [markdown]
# ## Methods

# %% [markdown]
# ## Results
#
# > "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Duis venenatis luctus ante sed interdum. Proin arcu urna, gravida vitae interdum et, congue ac metus. Cras ornare purus lacinia, convallis risus fringilla, accumsan erat. Aenean porttitor pellentesque tellus, a gravida mauris laoreet vitae."
# >
# >**AUTHOR (YEAR)**

# %% [markdown]
# ## Results
# #### *Table 1: Descriptive Statistics (N=192,830)*

# %%
styles = [
    dict(selector="th", props=[("font-size", "150%"),
                              ('text-align', 'center'),
                              ('font-weight', 'bold'),
                              ('color', '#000000'),
                              ('background-color', '#f7f7f9'),
                              ('width', '100px')]),
    dict(selector="td", props=[("font-size", "150%"),
                              ('background-color', '#FFFFFF'),
                              ('text-align', 'center')]),
    dict(selector="caption", props=[("caption-side", "bottom")])
]

with pd.option_context('display.precision', 3):
    html= (pd.read_csv(os.path.join('resources', 'desc_table.csv'), sep = ';', decimal = ',')\
        .set_index('var')
        .style.format(None, na_rep="-")
        .set_table_styles(styles)
        .set_caption("Own calculations using xxxx data"))

# %%
html
# Out:
# <style  type="text/css" >
#     #T_9c57c23a_753e_11eb_bacf_784f439a87aa th {
#           font-size: 150%;
#           text-align: center;
#           font-weight: bold;
#           color: #000000;
#           background-color: #f7f7f9;
#           width: 100px;
#     }    #T_9c57c23a_753e_11eb_bacf_784f439a87aa td {
#           font-size: 150%;
#           background-color: #FFFFFF;
#           text-align: center;
#     }    #T_9c57c23a_753e_11eb_bacf_784f439a87aa caption {
#           caption-side: bottom;
#     }</style><table id="T_9c57c23a_753e_11eb_bacf_784f439a87aa" ><caption>Own calculations using xxxx data</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >M</th>        <th class="col_heading level0 col1" >SD</th>        <th class="col_heading level0 col2" >MIN</th>        <th class="col_heading level0 col3" >MAX</th>    </tr>    <tr>        <th class="index_name level0" >var</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9c57c23a_753e_11eb_bacf_784f439a87aalevel0_row0" class="row_heading level0 row0" >y</th>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow0_col0" class="data row0 col0" >0.000</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow0_col1" class="data row0 col1" >1.231</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow0_col2" class="data row0 col2" >-3.000</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow0_col3" class="data row0 col3" >2.987</td>
#             </tr>
#             <tr>
#                         <th id="T_9c57c23a_753e_11eb_bacf_784f439a87aalevel0_row1" class="row_heading level0 row1" >x1</th>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow1_col0" class="data row1 col0" >0.600</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow1_col1" class="data row1 col1" >-</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow1_col2" class="data row1 col2" >0.000</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow1_col3" class="data row1 col3" >1.000</td>
#             </tr>
#             <tr>
#                         <th id="T_9c57c23a_753e_11eb_bacf_784f439a87aalevel0_row2" class="row_heading level0 row2" >x2</th>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow2_col0" class="data row2 col0" >5.320</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow2_col1" class="data row2 col1" >1.430</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow2_col2" class="data row2 col2" >0.000</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow2_col3" class="data row2 col3" >8.000</td>
#             </tr>
#             <tr>
#                         <th id="T_9c57c23a_753e_11eb_bacf_784f439a87aalevel0_row3" class="row_heading level0 row3" >x3</th>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow3_col0" class="data row3 col0" >7.000</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow3_col1" class="data row3 col1" >0.421</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow3_col2" class="data row3 col2" >5.000</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow3_col3" class="data row3 col3" >9.000</td>
#             </tr>
#             <tr>
#                         <th id="T_9c57c23a_753e_11eb_bacf_784f439a87aalevel0_row4" class="row_heading level0 row4" >x4</th>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow4_col0" class="data row4 col0" >0.000</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow4_col1" class="data row4 col1" >0.987</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow4_col2" class="data row4 col2" >-2.000</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow4_col3" class="data row4 col3" >2.000</td>
#             </tr>
#             <tr>
#                         <th id="T_9c57c23a_753e_11eb_bacf_784f439a87aalevel0_row5" class="row_heading level0 row5" >m1</th>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow5_col0" class="data row5 col0" >0.800</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow5_col1" class="data row5 col1" >0.234</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow5_col2" class="data row5 col2" >0.000</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow5_col3" class="data row5 col3" >1.000</td>
#             </tr>
#             <tr>
#                         <th id="T_9c57c23a_753e_11eb_bacf_784f439a87aalevel0_row6" class="row_heading level0 row6" >m2</th>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow6_col0" class="data row6 col0" >0.100</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow6_col1" class="data row6 col1" >0.129</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow6_col2" class="data row6 col2" >-2.000</td>
#                         <td id="T_9c57c23a_753e_11eb_bacf_784f439a87aarow6_col3" class="data row6 col3" >2.000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <div class="uu_title_container">
#     <div class='column'>
#         <br><br><br>
#         <h2>Thank You</h2>
#         <br><br>
#         <p><b>Contact:</b><br>Jos Slabbekoorn MSc.<br>Mail:&emsp;&emsp;&nbsp;<a href="mailto:your@email.com">your@email.com</a><br>Twitter:&emsp;<a href="https://twitter.com/XXXXX">@user_name</a><br>URL:&emsp;&emsp;<a href='https://www.yourdomain.com'>https://www.yourdomain.com</a></p>
#     </div>
#     <div class='column' id='frame'>
#         <br><br><br>
#         <figure><center><img id="undraw_col_img" src="./img/undraw_contact_us.svg"></center></figure>
#     </div>
# </div>

# %% [markdown]
# ## References & Resources
#
# Avila, D. (n.d.). *RISE: “Live” Reveal.js Jupyter/IPython Slideshow Extension*. Retrieved from https://github.com/damianavila/RISE
#
# Google Fonts. (n.d.). *Google Fonts*. Retrieved from: https://fonts.google.com/
#
# Limpitsouni, K. (n.d.). *Undraw /illustrations*. Retreived from: https://undraw.co.
